# %%
tl = 1

# %%
dolar = 40*tl

# %%
dolar
# Out:
# 40

# %%
MyAge=16

# %%
MyAge
# Out:
# 16

# %%
type("Yigido")
# Out:
# str

# %%
type(10)
# Out:
# int

# %%
type(10.5)
# Out:
# float

# %%
YigitsNumber=19838712743962154938758437856843657834

# %%
YigitsNumber
# Out:
# 19838712743962154938758437856843657834

# %%
YigitsNumber*2
# Out:
# 39677425487924309877516875713687315668

# %%
YigitsNumber*381273412698746712884
# Out:
# 7563973711440568530066556327023313753518001283010335333256

# %%
YigitsNumber*748618746812461729467812467128468912794851027519648721684612074678912489126401264721694512768546718240901248012704598175816581726417264891246127846128746781246787961872
# Out:
# 14851632272757362368085672410824729094255401444735451152389155966394684296258045247136930492754476204207498074954530549741516091886149822331627007186650464334366920316609985757337879187225946377802206105248

# %%
#omaygat

# %%
x = 100

# %%
type(x)
# Out:
# int

# %%
my_name="Yiğithan"

# %%
my_surname=" Hayta"

# %%
my_name+my_surname
# Out:
# 'Yiğithan Hayta'

# %%
type(my_name)
# Out:
# str

# %%
type(my_surname)
# Out:
# str

# %%
type(my_name + my_surname)
# Out:
# str

# %%
# my_name=snake_case
# myName=camelCase

# %%
yuhuu=10/2

# %%
yuhuu
# Out:
# 5.0

# %%
type(yuhuu)
# Out:
# float

# %%
4.5-1.5
# Out:
# 3.0

# %%
2**2
# Out:
# 4

# %%
2**4
# Out:
# 16

# %%
10%4
# Out:
# 2

# %%
#2**2= 2 üstü 2 
#10%4= bölümden kalanı veriyo
