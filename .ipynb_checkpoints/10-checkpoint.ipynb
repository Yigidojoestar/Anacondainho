# %%
def hello_python():
    print("Hello")
    print("Python")

# %%
hello_python()
# Out:
# Hello
# Python

# %%
def rastgele():
    a = 50
    while a <= 100:
        a = a + 10
        print("obaa")

# %%
rastgele()
# Out:
# obaa
# obaa
# obaa
# obaa
# obaa
# obaa

# %%
whologgedintdy=[]
def Login():
    Name=input("Please enter your name:")
    Password=input("Please enter your password:")
    if Name == "Yiğithan Hayta" and Password == "Eyh150110":
        print("Password is correct")
    else:
        print("Password is incorrect try again")
    if Password == "Eyh150110" and Name == "Yiğithan Hayta":
     print(f"Welcome Mr.{Name}.You have 3 mails and a missing call.You have a meeting at 15:00 p.m")
    if Password == "Eyh150110" and Name == "Yiğithan Hayta":
     whologgedintdy.append(Name+" logged in")

# %%
Login()
# Out:
# Please enter your name: Yiğithan Hayta
# Please enter your password: Eyh150110
# Password is correct
# Welcome Mr.Yiğithan Hayta.You have 3 mails and a missing call.You have a meeting at 15:00 p.m

# %%
whologgedintdy
# Out:
# ['Yiğithan Hayta logged in']

# %%
def toplama(num1,num2):
    num3 = num1 + num2
    print(num3)

# %%
toplama(9,99)
# Out:
# 108

# %%
def args_sum(*args):
    return sum(args)

# %%
args_sum(1,2,3,45,6,7,78,899)
# Out:
# 1041

# %%
def kwargs_example(**kwargs):
    print(kwargs)

# %%
kwargs_example(Yigithan=172,Neco=111,Tunc=7)
# Out:
# {'Yigithan': 172, 'Neco': 111, 'Tunc': 7}

# %%
def yarıyaböl(number):
    return(number/2)

# %%
yarıyaböl(2)
# Out:
# 1.0

# %%
yarıyaböl(12748612478215431728941423876478792347284)
# Out:
# 6.374306239107716e+39

# %%
myList=[3,5,7,10,20,30]

# %%
ResultList=[]
for num in myList:
    ResultList.append(yarıyaböl(num))

# %%
ResultList
# Out:
# [1.5, 2.5, 3.5, 5.0, 10.0, 15.0]

# %%
map(yarıyaböl,myList)

# %%
list(map(yarıyaböl,myList))
# Out:
# [1.5, 2.5, 3.5, 5.0, 10.0, 15.0]

# %%
def controlstring(string):
    return"Yigido" in string

# %%
Yigidoslist=["Yigido","Yigidos","Yigidosso","Yigithan"]

# %%
list(map(controlstring,Yigidoslist))
# Out:
# [True, True, True, False]

# %%
list(filter(controlstring,Yigidoslist))
# Out:
# ['Yigido', 'Yigidos', 'Yigidosso']

# %%
terimlerList=["Esterim","Biterim","Fatih Terim","Sarılara Biterim","Kraterim","Coğrafi Terim","Halterim","Yigithan"]

# %%
def terimbulucu(terim):
    return "terim" in terim or "Terim" in terim #ya da terim.lower()

# %%
list(filter(terimbulucu,terimlerList))
# Out:
# ['Esterim',
#  'Biterim',
#  'Fatih Terim',
#  'Sarılara Biterim',
#  'Kraterim',
#  'Coğrafi Terim',
#  'Halterim']

# %%
multiplyLambda= lambda num : num * 3

# %%
multiplyLambda(20)
# Out:
# 60

# %%
numList=[10,20,30,40,50]

# %%
list(map(lambda num:num/4,numList))
# Out:
# [2.5, 5.0, 7.5, 10.0, 12.5]
