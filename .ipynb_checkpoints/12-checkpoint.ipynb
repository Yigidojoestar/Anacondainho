# %%
age=input("enter age: ")
# Out:
# enter age:  15

# %%
age
# Out:
# '15'

# %%
int(age)*2
# Out:
# 30

# %%
while True:
 try:
    MyAge=int(input("Enter your age:"))
    print(MyAge*2)
    break
 except:
    print("Enter your age!")
# Out:
# Enter your age: Yiğit
# Enter your age!
# Enter your age: qyaresma
# Enter your age!
# Enter your age: Quaresma
# Enter your age!
# Enter your age: Murillo
# Enter your age!
# Enter your age: 15
# 30

# %%
try:
    Name=input("Enter you name:")
    print(int(Name))
except:
    print("Name already exists please try another name")
# Out:
# Enter you name: Yiğit
# Name already exists please try another name
