# %%
import numpy as np

# %%
my_list=[10,20,30,40,50,60]

# %%
np.array(my_list)
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
my_numpy_array=np.array(my_list)

# %%
type(my_numpy_array)
# Out:
# numpy.ndarray

# %%
my_numpy_array.mean()
# Out:
# np.float64(35.0)

# %%
my_numpy_array.min()
# Out:
# np.int64(10)

# %%
my_numpy_array
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
matrix_list=[[1,0,1],[0,0,1],[0,0,1],[0,1,0]]

# %%
matrix_numpy=np.array(matrix_list)

# %%
matrix_numpy
# Out:
# array([[1, 0, 1],
#        [0, 0, 1],
#        [0, 0, 1],
#        [0, 1, 0]])

# %%
matrix_numpy.shape
# Out:
# (4, 3)

# %%
np.random.randint(90,100)
# Out:
# 98

# %%
yeni_list=np.random.randint(1,150,25)

# %%
yeni_list
# Out:
# array([ 53, 111,  71,  39,  15, 142,  75, 149, 137,  24,  91,  60, 148,
#         92,  20,  77,  33,  29,  63, 128,  87,  80,  42, 126,  50],
#       dtype=int32)

# %%
yeni_list>50
# Out:
# array([ True,  True,  True, False, False,  True,  True,  True,  True,
#        False,  True,  True,  True,  True, False,  True, False, False,
#         True,  True,  True,  True, False,  True, False])

# %%
yeni_list>98
# Out:
# array([False,  True, False, False, False,  True, False,  True,  True,
#        False, False, False,  True, False, False, False, False, False,
#        False,  True, False, False, False,  True, False])

# %%
result_array=yeni_list>98

# %%
result_array
# Out:
# array([False,  True, False, False, False,  True, False,  True,  True,
#        False, False, False,  True, False, False, False, False, False,
#        False,  True, False, False, False,  True, False])

# %%
yeni_list[result_array]
# Out:
# array([111, 142, 149, 137, 148, 128, 126], dtype=int32)
