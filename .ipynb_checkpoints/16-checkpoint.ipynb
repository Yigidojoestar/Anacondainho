# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
age_list=[16,20,25,29]

# %%
weight_list=[66,70,79,79]

# %%
age_list_numpy=np.array(age_list)
weight_list_numpy=np.array(weight_list)

# %%
age_list_numpy
# Out:
# array([16, 20, 25, 29])

# %%
weight_list_numpy
# Out:
# array([66, 70, 79, 79])

# %%
plt.plot(age_list_numpy,weight_list_numpy,"purple")
plt.xlabel("Age")
plt.ylabel("Weight")
plt.title("Age-Weight Graphic")
# Out:
# Text(0.5, 1.0, 'Age-Weight Graphic')

# %%
sayıss=np.linspace(0,15,20)

# %%
sayıss
# Out:
# array([ 0.        ,  0.78947368,  1.57894737,  2.36842105,  3.15789474,
#         3.94736842,  4.73684211,  5.52631579,  6.31578947,  7.10526316,
#         7.89473684,  8.68421053,  9.47368421, 10.26315789, 11.05263158,
#        11.84210526, 12.63157895, 13.42105263, 14.21052632, 15.        ])

# %%
sayıss2=sayıss**3

# %%
sayıss2
# Out:
# array([0.00000000e+00, 4.92054235e-01, 3.93643388e+00, 1.32854644e+01,
#        3.14914711e+01, 6.15067794e+01, 1.06283715e+02, 1.68774603e+02,
#        2.51931768e+02, 3.58707538e+02, 4.92054235e+02, 6.54924187e+02,
#        8.50269719e+02, 1.08104315e+03, 1.35019682e+03, 1.66068304e+03,
#        2.01545415e+03, 2.41746246e+03, 2.86966030e+03, 3.37500000e+03])

# %%
plt.plot(sayıss,sayıss2,"r*")

# %%
plt.subplot(1,2,1)
plt.plot(sayıss,sayıss2,"r--")
plt.subplot(1,2,2)
plt.plot(sayıss2,sayıss,"b--")

# %%
figure=plt.figure()
axes=figure.add_axes([0.5,0.5,0.5,0.5])
axes.plot(sayıss,sayıss2,"r*")
axes.set_xlabel("Amann")
axes.set_ylabel("Vışşş")
axes.set_title("Abooo Harbi mi?")
# Out:
# Text(0.5, 1.0, 'Abooo Harbi mi?')

# %%
figure2=plt.figure()


axes3=figure2.add_axes([0.1,0.1,0.9,1])
axes3.plot(sayıss,sayıss2,"b--")
axes3.set_xlabel("Amannoha")
axes3.set_ylabel("Vışşşoha")
axes3.set_title("Abooo Harbi mioha?")


axes2=figure2.add_axes([0.4,0.7,0.3,0.3])
axes2.plot(sayıss,sayıss2,"r*")
axes2.set_xlabel("Amanno")
axes2.set_ylabel("Vışşşo")
axes2.set_title("Abooo Harbi mio?")
# Out:
# Text(0.5, 1.0, 'Abooo Harbi mio?')

# %%
(my_fig,my_axe)=plt.subplots()
my_axe.plot(sayıss,sayıss2,"black")
my_axe.plot(sayıss2,sayıss,"orange")

# %%
(new_fig,new_axe)=plt.subplots()
new_axe.plot(sayıss,sayıss + 2,"black",linewidth = 2.5,linestyle=":",marker="*",markersize=15)
new_axe.plot(sayıss,sayıss + 3,"orange",linewidth = 2.5,linestyle=":",marker="*",markersize=15)

# %%
(new_fig2,new_axe2)=plt.subplots()
new_axe2.plot(sayıss,sayıss + 2,"black",linewidth = 2.5,linestyle=":",marker="*",markersize=1000)
new_axe2.plot(sayıss,sayıss + 3,"orange",linewidth = 2.5,linestyle=":",marker="*",markersize=25)

# %%
plt.scatter(sayıss,sayıss2)

# %%
new_numpy=np.random.randint(0,100,40)

# %%
new_numpy
# Out:
# array([83, 92, 18, 77, 41, 93, 92, 96, 10, 73, 33, 56, 40, 48, 13, 72, 83,
#        13, 79, 54, 50, 78, 42, 92,  8, 47, 42, 94, 20, 80, 81, 47, 36, 38,
#        99, 93, 40, 23, 34, 26], dtype=int32)

# %%
plt.hist(new_numpy)
# Out:
# (array([4., 4., 2., 7., 4., 2., 0., 6., 3., 8.]),
#  array([ 8. , 17.1, 26.2, 35.3, 44.4, 53.5, 62.6, 71.7, 80.8, 89.9, 99. ]),
#  <BarContainer object of 10 artists>)
