# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
print("Merhaba Yigit")
# Out:
# Merhaba Yigit

# %%
name="Yiğithan Hayta"

# %%
name.capitalize()
# Out:
# 'Yiğithan hayta'

# %%
name.center
# Out:
# <function str.center(width, fillchar=' ', /)>

# %%
name.casefold()
# Out:
# 'yiğithan hayta'

# %%
name.count("a")
# Out:
# 3

# %%
name.encode()
# Out:
# b'Yi\xc4\x9fithan Hayta'

# %%
x=9

# %%
x.bit_count()
# Out:
# 2

# %%
x.bit_length()
# Out:
# 4

# %%
x.is_integer()
# Out:
# True

# %%
x.conjugate()
# Out:
# 9

# %%
x.to_bytes()
# Out:
# b'\t'

# %%
x.denominator
# Out:
# 1

# %%
x.imag
# Out:
# 0

# %%
x.real
# Out:
# 9

# %%
name.startswith("y")
# Out:
# False

# %%
name.endswith("a")
# Out:
# True

# %%
name.startswith("Y")
# Out:
# True

# %%
help(name.casefold)
# Out:
# Help on built-in function casefold:
#
# casefold() method of builtins.str instance
#     Return a version of the string suitable for caseless comparisons.

# %%
name.casefold()
# Out:
# 'yiğithan hayta'

# %%
name.expandtabs()
# Out:
# 'Yiğithan Hayta'

# %%
help(name.expandtabs)
# Out:
# Help on built-in function expandtabs:
#
# expandtabs(tabsize=8) method of builtins.str instance
#     Return a copy where all tab characters are expanded using spaces.
#
#     If tabsize is not given, a tab size of 8 characters is assumed.

# %%
name.upper()
# Out:
# 'YIĞITHAN HAYTA'

# %%
name
# Out:
# 'Yiğithan Hayta'

# %%
isim="Yiğithan"

# %%
soyisim=" Hayta"

# %%
tam_isim=isim + soyisim

# %%
tam_isim
# Out:
# 'Yiğithan Hayta'

# %%
nameUpper=name.upper()

# %%
nameUpper
# Out:
# 'YIĞITHAN HAYTA'

# %%
len(tam_isim)
# Out:
# 14

# %%
len(name)
# Out:
# 14

# %% [markdown]
# Index

# %%
myString="hello yigidos"

# %%
myString[3]
# Out:
# 'l'

# %%
myString[0]
# Out:
# 'h'

# %%
myString[len(myString)-1]
# Out:
# 's'

# %%
myString[-1]
# Out:
# 's'

# %%
myString[-4]
# Out:
# 'i'

# %%
barcode="ABCDE1243356478"

# %%
barcode[0:5:1]
# Out:
# 'ABCDE'

# %%
barcode[1:5:1]
# Out:
# 'BCDE'

# %%
barcode[:2:]
# Out:
# 'AB'

# %%
barcode[5::]
# Out:
# '1243356478'

# %%
barcodeName = barcode[:5:]

# %%
barcodeName
# Out:
# 'ABCDE'

# %%
barcodeCode=barcode[5::]

# %%
barcodeCode
# Out:
# '1243356478'

# %%
membershipCode="Yigit9999889"

# %%
memberName=membershipCode[:5:]

# %%
memberName
# Out:
# 'Yigit'

# %%
memberCode=membershipCode[5::]

# %%
memberCode
# Out:
# '9999889'

# %%
caseCode="922923Y55I009679"

# %%
caseCode[::3]
# Out:
# '99YI99'

# %%
caseCode[::-1]
# Out:
# '976900I55Y329229'

# %%
caseCode
# Out:
# '922923Y55I009679'
