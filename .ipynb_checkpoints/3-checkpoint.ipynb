# %%
myList=[90,9,99]

# %%
type(myList)
# Out:
# list

# %%
myList2=[7,10,27]

# %%
my_all_Lists=[myList,myList2]

# %%
my_all_Lists
# Out:
# [[90, 9, 99], [7, 10, 27]]

# %%
alınacaklarListesi=["Yumurta","Süt","Dondurma"]

# %%
alınacaklarListesi
# Out:
# ['Yumurta', 'Süt', 'Dondurma']

# %%
todoList=["Clean The House","Go Shopping","Make Food"]

# %%
todoList
# Out:
# ['Clean The House', 'Go Shopping', 'Make Food']

# %%
hmm=["sa,as,sasa,as,saas,assa"]

# %%
hmm
# Out:
# ['sa,as,sasa,as,saas,assa']

# %%
x=0
y=90
ye=12

# %%
obaa=[x,y,ye]

# %%
obaa
# Out:
# [0, 90, 12]

# %%
obaa[2]
# Out:
# 12

# %%
obaa[2]
# Out:
# 12

# %%
myList
# Out:
# [90, 9, 99]

# %%
myList[2]=12

# %%
myList
# Out:
# [90, 9, 12]

# %%
len(hmm)
# Out:
# 1

# %%
len(todoList)
# Out:
# 3

# %%
myList.index(90)
# Out:
# 0

# %%
myList
# Out:
# [90, 9, 12]

# %%
myList.append(99)

# %%
myList
# Out:
# [90, 9, 12, 99]

# %%
myList.insert(2,52)

# %%
myList
# Out:
# [90, 9, 52, 12, 99]

# %%
myList.remove(52)

# %%
myList
# Out:
# [90, 9, 12, 99]

# %%
myList.sort()

# %%
myList
# Out:
# [9, 12, 90, 99]

# %%
x = input("enter x")
# Out:
# enter x 13

# %%
Yaş = input("Yaşınızı girin=")
# Out:
# Yaşınızı girin= 16

# %%
Yaş
# Out:
# '16'

# %%
KullanıcıAdı=input("Kullanıcı Adı=")
Şifre=input("Şifre=")
# Out:
# Kullanıcı Adı= Yigit0052
# Şifre= Eyh150110

# %%
oyunBilgilerim=[]

# %%
oyunBilgilerim
# Out:
# []

# %%
#oyunBilgilerim.append(KullanıcıAdı + Şifre)

# %%
oyunBilgilerim.append(KullanıcıAdı)
oyunBilgilerim.append(Şifre)

# %%
oyunBilgilerim
# Out:
# ['Yigit0052', 'Eyh150110']

# %%
Yaş
# Out:
# '16'

# %%
type(Yaş)
# Out:
# str

# %%
int(Yaş)*2
# Out:
# 32

# %%
Yaş[0]*2
# Out:
# '11'

# %%
Yaş
# Out:
# '16'

# %%
Yaş*2
# Out:
# '1616'

# %%
int(Yaş)*2
# Out:
# 32

# %%
Yaş
# Out:
# '16'

# %%
myNestedList=[1,2,3,4,99,["Yiğit",99,4,],3,"yippa",9.12]

# %%
myNestedList
# Out:
# [1, 2, 3, 4, 99, ['Yiğit', 99, 4], 3, 'yippa', 9.12]

# %%
myNestedList[5][1]
# Out:
# 99
