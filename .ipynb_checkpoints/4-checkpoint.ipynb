# %%
calorie_list={"Banana":100,"Apple":250,}

# %%
type(calorie_list)
# Out:
# dict

# %%
calorie_list["Banana"]
# Out:
# 100

# %%
sınav_sonuçları={"Fizik":63,"Matematik":87,"Biyoloji":81}

# %%
sınav_sonuçları['Fizik']
# Out:
# 63

# %%
sınav_sonuçları.keys()
# Out:
# dict_keys(['Fizik', 'Matematik', 'Biyoloji'])

# %%
sınav_sonuçları.items()
# Out:
# dict_items([('Fizik', 63), ('Matematik', 87), ('Biyoloji', 81)])

# %%
sınav_sonuçları.fromkeys("Fizik")
# Out:
# {'F': None, 'i': None, 'z': None, 'k': None}

# %%
help(sınav_sonuçları.fromkeys)
# Out:
# Help on built-in function fromkeys:
#
# fromkeys(iterable, value=None, /) class method of builtins.dict
#     Create a new dictionary with keys from iterable and values set to value.

# %%
sınav_sonuçları.values()
# Out:
# dict_values([63, 87, 81])

# %%
sınav_sonuçları["Kimya"]=74

# %%
sınav_sonuçları
# Out:
# {'Fizik': 63, 'Matematik': 87, 'Biyoloji': 81, 'Kimya': 74}

# %%
membersNumber={23:"Alex",42:"Judy",99:"Yiğit",41:"Joseph"}

# %%
membersNumber[23]
# Out:
# 'Alex'

# %%
last_dictionary={"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %%
last_dictionary["k2"][3]
# Out:
# 40
