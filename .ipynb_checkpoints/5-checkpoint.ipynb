# %%
listem=[1,2,99,10,22,10,99,90]

# %%
listem
# Out:
# [1, 2, 99, 10, 22, 10, 99, 90]

# %%
len(listem)
# Out:
# 8

# %%
mySet=set(listem)

# %%
mySet
# Out:
# {1, 2, 10, 22, 90, 99}

# %%
mySet2={1,10,12,33,46,99}

# %%
mySet2
# Out:
# {1, 10, 12, 33, 46, 99}

# %%
mySet.union(mySet2)
# Out:
# {1, 2, 10, 12, 22, 33, 46, 90, 99}

# %%
mySet.intersection(mySet2)
# Out:
# {1, 10, 99}

# %%
girişyapanlar=[mySet.union(mySet2)]

# %%
girişyapanlar
# Out:
# [{1, 2, 10, 12, 22, 33, 46, 90, 99}]

# %%
birdenfazlaGirişyapnalar=[mySet.intersection(mySet2)]

# %%
birdenfazlaGirişyapnalar
# Out:
# [{1, 10, 99}]

# %%
emptySet={}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet=set()

# %%
type(emptySet)
# Out:
# set

# %%
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)
emptySet.add(40)

# %%
emptySet
# Out:
# {10, 20, 30, 40}
