# %%
tupleunho=("Yigigigi",10,99,9,52,"Yigido")

# %%
tupleunho
# Out:
# ('Yigigigi', 10, 99, 9, 52, 'Yigido')

# %%
type(tupleunho)
# Out:
# tuple

# %%
tupleunho[0]
# Out:
# 'Yigigigi'

# %%
#tupleunho[0]=100 olmuyo

# %% [markdown]
# Bool

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
benYigithan=True

# %%
benYigithan
# Out:
# True

# %%
99>9
# Out:
# True

# %%
9>99
# Out:
# False

# %%
9<99
# Out:
# True

# %%
myAge=16

# %%
yourAge=10

# %%
myAge>yourAge
# Out:
# True

# %%
workers=["Ali","Yiğit","Veli"]

# %%
"Yiğit" in workers
# Out:
# True

# %%
"Necati" in workers
# Out:
# False

# %%
YiğitAge=16

# %%
YiğitAge == 16
# Out:
# True

# %%
YiğitAge == 10
# Out:
# False

# %%
seninYaşın= input("Yaşınızı Giriniz =")
# Out:
# Yaşınızı Giriniz = 16

# %%
seninYaşın
# Out:
# '16'

# %%
int(seninYaşın)> 18
# Out:
# False
