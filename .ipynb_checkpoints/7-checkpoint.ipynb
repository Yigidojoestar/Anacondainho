# %%
x=9
y=9

# %%
x<=y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x >= 5
# Out:
# True

# %%
x > 7
# Out:
# True

# %%
a=9
b=10

# %%
x == y
# Out:
# True

# %%
x
# Out:
# 9

# %%
x == b
# Out:
# False

# %%
x != b
# Out:
# True

# %%
2 > 1 or 2 > 9
# Out:
# True

# %%
2 > 1 and 2 > 9
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False and False
# Out:
# False

# %%
not 1==1
# Out:
# False

# %%
not 1>2
# Out:
# True

# %%
abo=[1,2,3,4,5]

# %%
2 in abo
# Out:
# True

# %%
9 in abo
# Out:
# False

# %%
1 not in abo
# Out:
# False

# %%
9 not in abo
# Out:
# True

# %%
yu={1,2,3,4,45}

# %%
type(yu)
# Out:
# set

# %%
45 in yu
# Out:
# True

# %%
eyyo={1:"t","e":12}

# %%
type(eyyo)
# Out:
# dict

# %%
10 in eyyo
# Out:
# False

# %%
1 in eyyo
# Out:
# True

# %%
"t" in eyyo
# Out:
# False

# %%
"t" in eyyo.values()
# Out:
# True

# %%
"e" in eyyo.values()
# Out:
# False

# %%
"e" in eyyo.keys()
# Out:
# True

# %%
"t" in eyyo.keys()
# Out:
# False

# %%
ayyo=(10,20,30)

# %%
type(ayyo)
# Out:
# tuple

# %%
10 in ayyo
# Out:
# True

# %%
yuh=[1,2,3,4,5,6,77]

# %%
if 1 in yuh:
    print("yuh ya")
# Out:
# yuh ya

# %%
my_name = "Yiğithan"

# %%
if my_name == "Yiğithan":
    my_surname ="Hayta"

# %%
my_surname
# Out:
# 'Hayta'

# %%
if my_surname =="Hayta":
    print(my_name + my_surname)
# Out:
# YiğithanHayta

# %%
workers=["Ali","Mehmet","Necati","Yiğit"]

# %%
if "Yiğit" in workers:
    print("Welcome")
# Out:
# Welcome

# %%
if "Yavuz" in workers:
    print("Welcome")

# %%
if "Yavuz" not in workers:
    print("This computer is only authorized to workers!")
# Out:
# This computer is only authorized to workers!

# %%
name = input("Please enter your name:")
# Out:
# Please enter your name: Yiğit

# %%
if name in workers:
    print("Welcome")
elif name not in workers:
    print("This computer is only authorized to workers!")
# Out:
# Welcome
